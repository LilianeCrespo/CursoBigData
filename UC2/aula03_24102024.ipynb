# %% [markdown]
# Diferenças entre PANDAS E NUMPY

# %% [markdown]
# PANDAS:
#
# 1. Melhor forma de trabalhar com dados tabulares (dataframe).
# 2. As ferramentas poderosas são os comandos DATAFRAME e SERIES.
# 3. Possui melhor desempenho se o número de linhas da matriz precisar ser maior que 500K
# 4. Consome mais memória.
# 5. Oferece um recurso para visualizar tabelas 2D chamadas DATAFRAMES

# %% [markdown]
# NUMPY:
# 1. Melhor forma de trabalhar com dados numéricos (séries)
# 2. As ferrmaentas poderosas são os comandos DATAFRAME
# 3. Mais eficiente em termos de memória.
# 4. É mais eficiente quando o número de linhas do ARRAY é de 50K
# 5. Trabalha com MATRIZES MULTIDIMENSIONAIS
